# %%
# Import Libraries
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
import ruptures as rpt
from datetime import datetime
import os
from fredapi import Fred
import statsmodels.api as sm
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# Setup FRED API key
FRED_API_KEY = "b854a334011411eddeccad0687b69290"  # Replace with actual FRED API key
fred = Fred(api_key=FRED_API_KEY)

# File paths for data
data_dir = r"C:\Users\hayyu.ragea\AppData\Local\Programs\Python\Python312\Change point analysis\data\processed"
brent_data_path = os.path.join(data_dir, "cleaned_brent_oil_prices.csv")
events_data_path = os.path.join(data_dir, "cleaned_events_data.csv")

# Download historical Brent oil prices
def download_data():
    ticker = "BZ=F"
    start_date = "1987-05-20"
    end_date = "2022-09-30"
    data = yf.download(ticker, start=start_date, end=end_date)
    data = data[["Close"]].rename(columns={"Close": "Price"})
    data.index.name = "Date"
    return data

# Load data function
def load_data():
    if os.path.exists(brent_data_path):
        data = pd.read_csv(brent_data_path, index_col="Date", parse_dates=True)
    else:
        data = download_data()
        data.to_csv(brent_data_path)
    return data

# Fetch economic data
def fetch_economic_data():
    gdp_growth = fred.get_series("GDP")
    inflation = fred.get_series("CPIAUCSL")
    unemployment = fred.get_series("UNRATE")
    usd_index = fred.get_series("DTWEXBGS")
    economic_data = pd.DataFrame(
        {"GDP_Growth": gdp_growth, "Inflation": inflation, "Unemployment": unemployment, "USD_Index": usd_index}
    )
    economic_data.index = pd.to_datetime(economic_data.index)
    economic_data = economic_data.resample("M").mean()
    return economic_data

# Merge oil prices with economic data
def merge_data_with_oil_prices(oil_data, economic_data):
    merged_data = oil_data.join(economic_data, how="inner")
    merged_data.dropna(inplace=True)
    return merged_data

# EDA
def eda(data):
    print(data.describe())
    plt.figure(figsize=(14, 7))
    plt.plot(data["Price"], label="Brent Oil Price")
    plt.title("Brent Oil Prices Over Time")
    plt.xlabel("Date")
    plt.ylabel("Price (USD per barrel)")
    plt.legend()
    plt.show()
    result = adfuller(data["Price"])
    print("ADF Statistic:", result[0], "\np-value:", result[1])
    print("Data is stationary" if result[1] <= 0.05 else "Data is non-stationary")

# Change Point Detection
def change_point_detection(data):
    series = data["Price"].values
    algo = rpt.Binseg(model="l2").fit(series)
    change_points = algo.predict(n_bkps=10)
    plt.figure(figsize=(14, 7))
    plt.plot(series, label="Brent Oil Price")
    for cp in change_points:
        plt.axvline(cp, color="r", linestyle="--", label="Change Point" if cp == change_points[0] else "")
    plt.title("Change Point Analysis on Brent Oil Prices")
    plt.xlabel("Time")
    plt.ylabel("Price (USD per barrel)")
    plt.legend()
    plt.show()
    return change_points

# ARIMA Modeling
def time_series_modeling(data, order=(1, 1, 1)):
    model = ARIMA(data["Price"], order=order)
    fitted_model = model.fit()
    print(fitted_model.summary())
    forecast = fitted_model.forecast(steps=30)
    plt.figure(figsize=(14, 7))
    plt.plot(data["Price"], label="Original")
    plt.plot(forecast, label="Forecast", color="red")
    plt.title("ARIMA Model Forecast")
    plt.xlabel("Date")
    plt.ylabel("Price (USD per barrel)")
    plt.legend()
    plt.show()
    return fitted_model

# Analyze Economic Factors
def analyze_economic_factors(merged_data):
    sns.heatmap(merged_data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
    plt.title("Correlation Matrix")
    plt.show()
    for col in ["GDP_Growth", "Inflation", "Unemployment", "USD_Index"]:
        X = sm.add_constant(merged_data[col])
        model = sm.OLS(merged_data["Price"], X).fit()
        print(f"Regression analysis for {col}:\n", model.summary())

# LSTM Forecasting
def lstm_forecasting(data):
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(data["Price"].values.reshape(-1, 1))
    def create_dataset(dataset, time_step=1):
        X, Y = [], []
        for i in range(len(dataset) - time_step - 1):
            X.append(dataset[i: (i + time_step), 0])
            Y.append(dataset[i + time_step, 0])
        return np.array(X), np.array(Y)
    time_step = 10
    X, Y = create_dataset(scaled_data, time_step)
    X = X.reshape(X.shape[0], X.shape[1], 1)
    model = Sequential([
        LSTM(50, return_sequences=True, input_shape=(X.shape[1], 1)), Dropout(0.2),
        LSTM(50, return_sequences=False), Dropout(0.2),
        Dense(1)
    ])
    model.compile(loss="mean_squared_error", optimizer="adam")
    model.fit(X, Y, epochs=100, batch_size=32)
    predictions = scaler.inverse_transform(model.predict(X))
    plt.figure(figsize=(14, 7))
    plt.plot(data["Price"], label="Original Price")
    plt.plot(np.arange(time_step, len(predictions) + time_step), predictions, label="LSTM Forecast", color="red")
    plt.title("LSTM Model Forecast")
    plt.xlabel("Date")
    plt.ylabel("Price (USD per barrel)")
    plt.legend()
    plt.show()

# Main function
def main():
    oil_data = load_data()
    economic_data = fetch_economic_data()
    merged_data = merge_data_with_oil_prices(oil_data, economic_data)
    eda(merged_data)
    change_points = change_point_detection(merged_data)
    time_series_modeling(merged_data)
    analyze_economic_factors(merged_data)
    lstm_forecasting(merged_data)

# Execute all functions
main()
# Out:
# C:\Users\hayyu.ragea\AppData\Local\Temp\ipykernel_8428\3153077590.py:56: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   economic_data = economic_data.resample("M").mean()
#             Price    GDP_Growth   Inflation  Unemployment   USD_Index
# count   61.000000     61.000000   61.000000     61.000000   61.000000
# mean    78.240965  18441.071951  239.065279      6.359016  103.125593
# std     26.082479   3246.251355   20.199635      2.347863   11.345616
# min     26.631429  14381.236000  207.603000      3.500000   86.317805
# 25%     56.621818  15557.539000  224.093000      4.500000   92.440300
# 50%     74.795239  18063.529000  237.430000      5.700000  103.760740
# 75%    104.705000  20798.730000  252.561000      8.200000  114.075755
# max    134.099545  26272.011000  294.977000     14.800000  123.289350
# ADF Statistic: -2.1761686625497942
# p-value: 0.2150082585602031
# Data is non-stationary
# c:\Users\hayyu.ragea\AppData\Local\Programs\Python\Python312\Change point analysis\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QE-OCT will be used.
#   self._init_dates(dates, freq)
# c:\Users\hayyu.ragea\AppData\Local\Programs\Python\Python312\Change point analysis\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QE-OCT will be used.
#   self._init_dates(dates, freq)
# c:\Users\hayyu.ragea\AppData\Local\Programs\Python\Python312\Change point analysis\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QE-OCT will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                   61
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -246.142
# Date:                Thu, 07 Nov 2024   AIC                            498.285
# Time:                        10:05:33   BIC                            504.568
# Sample:                    07-31-2007   HQIC                           500.742
#                          - 07-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8566      0.117      7.310      0.000       0.627       1.086
# ma.L1         -0.9997      8.568     -0.117      0.907     -17.793      15.794
# sigma2       208.1543   1762.914      0.118      0.906   -3247.093    3663.402
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.50   Jarque-Bera (JB):                40.71
# Prob(Q):                              0.48   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.47   Skew:                            -1.38
# Prob(H) (two-sided):                  0.10   Kurtosis:                         5.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Regression analysis for GDP_Growth:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     5.166
# Date:                Thu, 07 Nov 2024   Prob (F-statistic):             0.0267
# Time:                        10:05:34   Log-Likelihood:                -282.43
# No. Observations:                  61   AIC:                             568.9
# Df Residuals:                      59   BIC:                             573.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        120.2823     18.777      6.406      0.000      82.710     157.854
# GDP_Growth    -0.0023      0.001     -2.273      0.027      -0.004      -0.000
# ==============================================================================
# Omnibus:                        7.344   Durbin-Watson:                   0.382
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):                2.654
# Skew:                           0.089   Prob(JB):                        0.265
# Kurtosis:                       1.994   Cond. No.                     1.09e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.09e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression analysis for Inflation:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     2.560
# Date:                Thu, 07 Nov 2024   Prob (F-statistic):              0.115
# Time:                        10:05:34   Log-Likelihood:                -283.69
# No. Observations:                  61   AIC:                             571.4
# Df Residuals:                      59   BIC:                             575.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        141.1880     39.481      3.576      0.001      62.186     220.190
# Inflation     -0.2633      0.165     -1.600      0.115      -0.593       0.066
# ==============================================================================
# Omnibus:                        9.619   Durbin-Watson:                   0.364
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                3.097
# Skew:                           0.136   Prob(JB):                        0.213
# Kurtosis:                       1.930   Cond. No.                     2.87e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.87e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression analysis for Unemployment:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.8899
# Date:                Thu, 07 Nov 2024   Prob (F-statistic):              0.349
# Time:                        10:05:34   Log-Likelihood:                -284.53
# No. Observations:                  61   AIC:                             573.1
# Df Residuals:                      59   BIC:                             577.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           69.6297      9.721      7.163      0.000      50.178      89.081
# Unemployment     1.3542      1.435      0.943      0.349      -1.518       4.227
# ==============================================================================
# Omnibus:                        2.316   Durbin-Watson:                   0.380
# Prob(Omnibus):                  0.314   Jarque-Bera (JB):                1.423
# Skew:                           0.006   Prob(JB):                        0.491
# Kurtosis:                       2.252   Cond. No.                         20.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression analysis for USD_Index:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.479
# Model:                            OLS   Adj. R-squared:                  0.471
# Method:                 Least Squares   F-statistic:                     54.32
# Date:                Thu, 07 Nov 2024   Prob (F-statistic):           6.38e-10
# Time:                        10:05:34   Log-Likelihood:                -265.08
# No. Observations:                  61   AIC:                             534.2
# Df Residuals:                      59   BIC:                             538.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        242.3813     22.403     10.819      0.000     197.553     287.209
# USD_Index     -1.5917      0.216     -7.370      0.000      -2.024      -1.160
# ==============================================================================
# Omnibus:                        4.542   Durbin-Watson:                   0.416
# Prob(Omnibus):                  0.103   Jarque-Bera (JB):                3.599
# Skew:                           0.550   Prob(JB):                        0.165
# Kurtosis:                       3.455   Cond. No.                         956.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Epoch 1/100
# c:\Users\hayyu.ragea\AppData\Local\Programs\Python\Python312\Change point analysis\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.2713
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1889
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1378
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0839
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0557
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0515
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0670
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0664
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0598
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0492
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0503
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0534
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0508
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0483
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0561
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0439
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0481
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0485
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0451
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0494
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0500
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0494
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0406
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0448
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0479
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0448
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0494
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0535
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0396
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0405
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0392
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0439
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0463
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0373
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0410
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0413
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0436
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0424
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0474
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0328
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0404
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0393
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0393
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0389
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0344
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0340
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0407
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0339
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0358
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0367
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0348
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0343
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0370
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0363
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0328
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0342
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0352
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0359
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0346
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0311
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0280
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0263
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0361
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0355
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0262
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0291
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0320
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0322
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0300
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0303
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0301
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0279
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0324
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0277
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0248
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0332
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0280
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0239
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0279
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0267
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0257
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0262
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0246
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0314
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0240
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0244
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0284
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0237
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0238
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0206
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0285
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0233
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0244
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0220
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0264
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0241
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0263
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0248
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0281
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0245
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step
